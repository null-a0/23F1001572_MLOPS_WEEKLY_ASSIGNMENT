# %% [markdown]
# # Install Feast, scikit-learn and GCP support

# %%
# !pip install feast scikit-learn "feast[gcp]"
# Out:
# WARNING: Ignoring invalid distribution ~oogle-auth (/opt/micromamba/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~oogle-auth (/opt/micromamba/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~oogle-auth (/opt/micromamba/lib/python3.12/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~oogle-auth (/opt/micromamba/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~oogle-auth (/opt/micromamba/lib/python3.12/site-packages)

# %% [markdown]
# ## Checking feast Version

# %%
# !feast version
# Out:
# Feast SDK Version: "0.64.0"
